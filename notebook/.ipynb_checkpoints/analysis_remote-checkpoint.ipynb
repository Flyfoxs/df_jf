# %%
import sys
import os
import pandas as pd

from bokeh.palettes import Category10


from file_cache.utils.util_pandas import *
from file_cache.cache import file_cache

import matplotlib.pyplot as plt

#Adjust the working folder
file_folder = globals()['_dh'][0]
wk_dir = os.path.dirname(file_folder)
os.chdir(wk_dir)
from core.feature import *
from core.train import *
logging.getLogger().setLevel(logging.DEBUG)

import argparse
sys.argv = ['program',  '--file_num',  '1', '--cut_len', '200', '--top_threshold', '0.5']

args = options()
args
# Out:
# 2019-01-29 00:25:36,220 util_log.py[61] DEBUG Start the program at:ai-prd-01, 173.36.99.79, with:Load module
# Namespace(cut_len=200, debug=True, file_num=1, top_threshold=0.5, version='0129')

# %%
file = "./cache/check_score_all=Namespace(cut_len=100, debug=True, file_num=0, top_threshold=0_6, version='0129')=pic=False.h5"

df = pd.read_hdf(file)

df.sort_values('score_1_file')
# Out:
#        data_type        mean                              coef_wtid_avg coef_wtid_max coef_wtid_id score_1_file score_2_file score_3_file score_4_file score_5_file
#                         mean      min      max        std
# col
# var031   float64   10.978636    5.704   16.104   2.642671      0.528991      0.717980     var031_8       0.0054       0.0060       0.0065       0.0064       0.0069
# var046   float64  171.546758  140.190  211.478  18.261798      0.867737      0.915827    var046_29       0.0566       0.0524       0.0536       0.0543       0.0545
# var042   float64  170.388182  138.787  209.913  18.030330      0.865872      0.914564    var042_29       0.0567       0.0530       0.0533       0.0540       0.0541
# var034   float64  213.465182  175.160  244.824  18.852027      0.857280      0.902715    var034_30       0.0590       0.0537       0.0548       0.0552       0.0552
# var004   float64  170.502364  138.287  209.432  18.300956      0.867374      0.915553    var004_30       0.0592       0.0528       0.0537       0.0542       0.0546
# var027   float64    1.255061    1.066    1.867   0.150603      0.903429      0.937481    var027_29       0.0630       0.0612       0.0622       0.0626       0.0631
# var015   float64   20.727576   16.696   26.519   2.454227      0.237618      0.343390     var015_8       0.0803       0.0855       0.0864       0.0866       0.0868
# var043   float64  212.627727  178.422  267.437  21.011827      0.873247      0.919313    var043_26       0.0949       0.0921       0.0923       0.0927       0.0930
# var061   float64   13.412061    7.701   18.844   2.758167      0.413723      0.583546     var061_8       0.1298       0.1343       0.1355       0.1368       0.1379
# var054   float64    2.173030    1.794    3.482   0.413833      0.215777      0.704274    var054_23       0.1511       0.1581       0.1591       0.1586       0.1570
# var068   float64    2.230788    1.545    2.897   0.305470      0.873659      0.911564    var068_26       0.1701       0.1512       0.1558       0.1617       0.1609
# var041   float64    0.044121    0.031    0.057   0.006845      0.079614      0.107174    var041_12       0.2595       0.3069       0.2977       0.2918       0.2881
# var023   float64    0.010273    0.004    0.025   0.005088      0.188613      0.438249     var023_7       0.2635       0.2616       0.2615       0.2614       0.2619
# var056   float64   25.636030    5.746   65.001  13.961330      0.792466      0.957303    var056_29       0.3322       0.3159       0.3338       0.3391       0.3415
# var003   float64    4.097939    2.678    8.726   1.180628      0.970426      0.993070    var003_27       0.3588       0.4217       0.4438       0.4433       0.4428
# var017   float64    0.149333    0.009    1.295   0.337874      0.226047      0.517646    var017_11       0.9470       0.9373       0.9405       0.9411       0.9441
# var009   float64    0.154576    0.009    1.304   0.356192      0.255153      0.528810     var009_4       0.9491       0.9457       0.9456       0.9459       0.9462
# var063   float64    0.146364    0.007    1.292   0.331320      0.232793      0.426289    var063_27       0.9609       0.9539       0.9557       0.9559       0.9564
# var048   float64    0.077788    0.007    0.657   0.166329      0.223184      0.374513     var048_4       0.9613       0.9539       0.9553       0.9559       0.9563
# var020     int16    1.758152    0.000   18.731   3.904348      0.214968      0.899669    var020_33       0.9896       0.9770       0.9770       0.9770       0.9770
# var047     int16    0.007667    0.000    0.053   0.012927      0.682831      0.980348     var047_9       0.9955       0.9979       0.9979       0.9979       0.9979
# var066     int16    0.006545    0.000    0.037   0.010423      0.674125      0.982638     var066_9       0.9955       0.9979       0.9979       0.9979       0.9979

# %%
tmp = pd.read_hdf('./cache/check_score_all==version=lg.h5')


round(tmp.iloc[:, -5].mean(), 4) , round(tmp.iloc[:, -5:].max(axis=1).mean(), 4)
# Out:
# (0.5362, 0.5386)

# %%
train

# %%
score_df = check_score_all(version='0126')#.reset_index()  
score_df
score_df.iloc[:, -5:].idxmax(axis=1).sort_values()

# %%
for wtid in range(1,2):
    group_list = group_columns(wtid=1)
    for group in group_list:
        logger.debug(f'Current group:{group}')
        train = get_train_ex(wtid)
        train = train[group]   
        logger.debug(f'Old len = {len(train)}')
        train = train.dropna(how='all')
        logger.debug(f'New len = {len(train)}')
        print(len(train), train.where(pd.isna(train), 1).sum())

# %%
logging.getLogger().setLevel(logging.WARNING)
train_list = []
from tqdm import tqdm
for wtid in tqdm(range(1, 3)):
    train_ex =  predict_wtid(wtid)
    train_ex = train_ex.set_index(['ts', 'wtid'])
    train_list.append(train_ex)
submit = pd.concat(train_list)

# %%
get_closed_columns('var034')

# %%
score_df.score.mean()

# %% [markdown]
# ## Validate  Score

# %%
 

#check_score(col, pic=True)
score_df = check_score_all(False)

score_df

# %% [markdown]
# ## Analysis the std of the column

# %%
std = get_std_all()
std = std.groupby(['col', 'data_type']).agg({'mean': ['mean', 'min', 'max', 'std']})   

std = std.reset_index().set_index('col')
std

# %% [markdown]
# ## get corr between wtid for special col

# %%
get_corr_wtid('var034')

# %% [markdown]
# ## Get corrcoef matrix within wtid

# %%
sub = get_train_ex(1)

sub = sub.dropna(how='any')

cor = np.corrcoef(sub.drop(axis='column', columns=['ts','wtid']).T)

col_list = sub.columns[2:]

print(cor.shape, sub.shape)

cor1 = pd.DataFrame(index=col_list, columns=col_list, data=np.where(abs(cor)>0, cor, 0) )

cor1

# %% [markdown]
# ## Visual missing block

# %%
import matplotlib.pyplot as plt
for wtid in range(1, 5):
    block_list = get_blocks()
    block_list = block_list.loc[(block_list.wtid==wtid) &(block_list.kind=='missing') ]
    block_list

    plt.figure(figsize=(20,10))


    for col_name in block_list.col.drop_duplicates().sort_values().values:
        #print(col_name)
        block_sub = block_list.loc[block_list['col'] == col_name]

        for index, block in block_sub.iterrows():
            sn = int(block['col'][-3:])
            plt.plot([block.begin, block.end], [sn, sn], color=Category10[10][sn%10] )


plt.show()

# %% [markdown]
# ## Visual missing block(For special col)

# %%
import matplotlib.pyplot as plt
block = adjust_block(ratio = 1)
col_name = 'var011'
for wtid in range(1, 5):
    block_list = adjust_block()
    block_list = block_list.loc[(block_list.wtid==wtid) &(block_list.kind=='missing') ]
    block_list

    plt.figure(figsize=(20,3))

    count = 0

    for col_name in get_closed_columns(col_name,threshold=0.8):
        #print(col_name)
        block_sub = block_list.loc[block_list['col'] == col_name].reset_index()
        
        count += 1
        for index, block in block_sub.iterrows():
            #sn = int(block['col'][-3:])
            plt.plot([block.begin_ex, block.end_ex], [count, count], color=Category10[10][index%10] )

plt.show()

# %%
block2 = block[(block.wtid < 5) &(block.col=='var003') & (block.kind=='missing')]
block2.end_ex.max(), block2.end.max()
#block.loc[(block.wtid==1) &(block.col=='var001')&(block.kind=='missing')]

# %% [markdown]
# ## Main

# %%
block_list = get_blocks()
for wtid in range(1, 2):
    train_ex = get_train_ex(wtid)
    for blockid, missing_block in block_list.loc[(block_list.wtid == wtid) & (block_list.kind == 'missing')].iterrows():
        col_name = missing_block.col
        train, sub = get_submit_feature_by_block_id(blockid)
        logger.info(f'blockid:{blockid}, train:{train.shape}')
        predict_fn = get_predict_fun(blockid, train)
        predict_res = predict_fn(sub.time_sn)
        sub[col_name] = predict_res
        logger.debug(f'predict_res:{predict_res.shape}, {type(predict_res)}')
        begin, end = missing_block.begin, missing_block.end

        logger.debug(f'train.loc[begin:end,col_name] = {train_ex.loc[begin:end,col_name].shape}, {begin}, {end}, {wtid}, {col_name}')
        train_ex.loc[begin:end,col_name] = predict_res
        
train_ex

# %% [markdown]
# ## VIsual predict result

# %%
import sys
import os
import pandas as pd

from bokeh.palettes import Category10


from file_cache.utils.util_pandas import *
from file_cache.cache import file_cache

import matplotlib.pyplot as plt

#Adjust the working folder
file_folder = globals()['_dh'][0]
wk_dir = os.path.dirname(file_folder)
os.chdir(wk_dir)
from core.feature import *
from core.train import *
logging.getLogger().setLevel(logging.DEBUG)
################

logging.getLogger().setLevel(logging.INFO)
import matplotlib.pyplot as plt

sys.argv = ['program',  '--file_num',  '1', '--cut_len', '600', '--top_threshold', '0.5']
args = options()
args
print(args)
    
    
time_enable = False
col =  'var034' #'var018'
train_list = get_train_feature(5, col, args )

train_list = sorted(train_list, key=lambda val: len(val[1]), reverse=True)

count, loss = 0, 0
for train, val, blockid in train_list[:1]:
    plt.figure(figsize=(20,5))
    is_enum = True if 'int' in date_type[col].__name__ else False
    
#     if is_enum:
#         fn = lambda val:  np.full_like(val,train[col].value_counts().index[0])
#     else:    
#         w = np.polyfit (train.time_sn, train[col], 1)
#         fn = np.poly1d(w)
    if  time_enable or args.file_num==1 :
        train_bk = train 
        val_bk = val 
        
    else:
        train_bk = train.drop(axis='column', columns=['time_sn'])
        val_bk = val.drop(axis='column', columns=['time_sn'])

        
    print('shape',train_bk.shape, val_bk.shape, val_bk.columns)
    fn = get_predict_fun(blockid,train_bk, args)
    

    for color, data in zip(Category10[5][:2], [train, val]):
        plt.scatter(data.time_sn, data[col], c= color, alpha=0.1)
        
    plt.scatter(val.time_sn, fn(val_bk.iloc[:, 1:]), c= Category10[5][3])
    
    
    if args.file_num==1:
        x = np.linspace(train.time_sn.min(), train.time_sn.max(), 100)
        plt.plot(x, fn(np.expand_dims(x, axis=1))) 
    
    
    
    print(val[col].shape, val.iloc[:, 1:].shape)
    
    cur_count, cur_loss = score(val[col], fn(val_bk.iloc[:, 1:]), is_enum)
    
    #print(cur_loss, cur_count)                            
    loss  += cur_loss 
    count += cur_count 
    


    logger.info(f'blockid:{blockid}, {train.shape}, {val.shape}, score={round(cur_loss/cur_count,3)}')
print(f'Total loss====:{round(loss/count, 4)}, is_enum:{is_enum}, file_num:{args.file_num}, time_enable:{time_enable}')

plt.show()
# Out:
# 2019-01-29 02:49:59,450 feature.py[253] DEBUG file_num=1, at_least_len=82, window=24, missing_len=34 (24, 10)
# 2019-01-29 02:49:59,541 feature.py[253] DEBUG file_num=1, at_least_len=82, window=24, missing_len=34 (24, 10)
# Namespace(cut_len=600, debug=True, file_num=1, top_threshold=0.5, version='0129')
# 2019-01-29 02:49:59,625 feature.py[253] DEBUG file_num=1, at_least_len=206, window=60, missing_len=86 (23, 10)
# 2019-01-29 02:49:59,706 feature.py[253] DEBUG file_num=1, at_least_len=206, window=60, missing_len=86 (23, 10)
# 2019-01-29 02:49:59,785 feature.py[253] DEBUG file_num=1, at_least_len=254, window=74, missing_len=106 (23, 10)
# 2019-01-29 02:49:59,949 feature.py[253] DEBUG file_num=1, at_least_len=398, window=116, missing_len=166 (23, 10)
# 2019-01-29 02:50:00,030 feature.py[253] DEBUG file_num=1, at_least_len=445, window=130, missing_len=185 (23, 10)
# 2019-01-29 02:50:00,112 feature.py[253] DEBUG file_num=1, at_least_len=497, window=145, missing_len=207 (23, 10)
# 2019-01-29 02:50:00,200 feature.py[253] DEBUG file_num=1, at_least_len=562, window=164, missing_len=234 (23, 10)
# 2019-01-29 02:50:00,276 feature.py[253] DEBUG file_num=1, at_least_len=737, window=215, missing_len=307 (23, 10)
# 2019-01-29 02:50:00,353 feature.py[253] DEBUG file_num=1, at_least_len=813, window=237, missing_len=339 (23, 10)
# 2019-01-29 02:50:00,430 feature.py[253] DEBUG file_num=1, at_least_len=915, window=267, missing_len=381 (23, 10)
# 2019-01-29 02:50:00,511 feature.py[253] DEBUG file_num=1, at_least_len=988, window=288, missing_len=412 (22, 10)
# 2019-01-29 02:50:00,586 feature.py[253] DEBUG file_num=1, at_least_len=1091, window=318, missing_len=455 (22, 10)
# 2019-01-29 02:50:00,662 feature.py[253] DEBUG file_num=1, at_least_len=1139, window=332, missing_len=475 (22, 10)
# 2019-01-29 02:50:00,737 feature.py[253] DEBUG file_num=1, at_least_len=1306, window=381, missing_len=544 (22, 10)
# 2019-01-29 02:50:00,813 feature.py[253] DEBUG file_num=1, at_least_len=1478, window=431, missing_len=616 (20, 10)
# 2019-01-29 02:50:00,884 feature.py[253] DEBUG file_num=1, at_least_len=1885, window=550, missing_len=785 (20, 10)
# 2019-01-29 02:50:00,956 feature.py[253] DEBUG file_num=1, at_least_len=2352, window=686, missing_len=980 (19, 10)
# 2019-01-29 02:50:01,021 feature.py[253] DEBUG file_num=1, at_least_len=2719, window=793, missing_len=1133 (18, 10)
# 2019-01-29 02:50:01,084 feature.py[253] DEBUG file_num=1, at_least_len=2791, window=814, missing_len=1163 (18, 10)
# 2019-01-29 02:50:01,148 feature.py[253] DEBUG file_num=1, at_least_len=2986, window=871, missing_len=1244 (18, 10)
# 2019-01-29 02:50:01,215 feature.py[253] DEBUG file_num=1, at_least_len=3250, window=948, missing_len=1354 (18, 10)
# 2019-01-29 02:50:01,315 train.py[46] DEBUG val block:[4264, 5617], Index(['time_sn'], dtype='object')
# 2019-01-29 02:50:01,316 train.py[48] DEBUG train:(1896, 2), val(1354, 1)
# 2019-01-29 02:50:01,323 train.py[46] DEBUG val block:[4264, 5617], Index(['time_sn'], dtype='object')
# 2019-01-29 02:50:01,324 train.py[48] DEBUG train:(1896, 2), val(1354, 1)
# 2019-01-29 02:50:01,334 <ipython-input-5-9515fa7fe2d3>[83] INFO blockid:14795, (1896, 2), (1354, 2), score=0.029
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# shape (1896, 2) (1354, 2) Index(['var034', 'time_sn'], dtype='object')
# (1354,) (1354, 1)
# Total loss====:0.0289, is_enum:False, file_num:1, time_enable:False

# %%
#train_bk.shape, val_bk
val_bk.head()
# Out:
#        var034
# 13720  297.35
# 13721  391.00
# 13722  391.00
# 13723  433.56
# 13724  266.18

# %%
val
# Out:
#       var018    time_sn
# 4264   35.20  31417.249
# 4265   35.20  31424.612
# 4266   35.20  31431.979
# 4267   35.20  31439.344
# 4268   35.20  31446.713
# 4269   35.20  31454.077
# 4270   35.20  31461.442
# 4271   35.20  31468.808
# 4272   35.20  31476.174
# 4273   35.20  31483.540
# 4274   35.20  31490.907
# 4275   35.20  31498.273
# 4276   35.20  31505.642
# 4277   35.20  31513.005
# 4278   35.20  31520.371
# 4279   35.20  31527.739
# 4280   35.20  31535.222
# 4281   35.20  31542.588
# 4282   35.20  31549.954
# 4283   35.20  31557.320
# 4284   35.20  31564.687
# 4285   35.20  31572.052
# 4286   35.20  31579.419
# 4287   35.20  31586.785
# 4288   35.20  31594.150
# 4289   35.20  31601.516
# 4290   35.20  31608.882
# 4291   35.20  31616.248
# 4292   35.20  31623.614
# 4293   35.20  31630.981
# 4294   35.20  31638.347
# 4295   35.20  31645.713
# 4296   35.20  31653.079
# 4297   35.20  31660.444
# 4298   35.20  31667.810
# 4299   35.20  31675.176
# 4300   35.20  31682.543
# 4301   35.20  31689.909
# 4302   35.20  31697.275
# 4303   35.20  31704.642
# 4304   35.20  31712.006
X = np.random.randn(n_samples, 1)
print(X.shape)
print(y.shape)
clf = Ridge(alpha=1.0)
clf.fit(X, y)

# %% [markdown]
# ## Visual submit data

# %%
import matplotlib.pyplot as plt

block = get_blocks() 
wtid = 1
col = 'var001'
missing_block = block.loc[(block.wtid == wtid) & (block.col == col) & (block.kind == 'missing')]
missing_block
for blockid, row in missing_block[:5].iterrows():
    train, sub = get_submit_feature_by_block_id(blockid)
    logger.info(f'blockid:{blockid}, train:{train.shape}')
    predict_fn = get_predict_fun(blockid, train)
    predict_res = predict_fn(sub.time_sn)
    sub[col] = predict_res
    
    for color, data in zip(Category10[5][:2], [train, sub]):
        plt.scatter(data.time_sn, data[col], c= color)
    
    x = np.linspace(train.time_sn.min(), train.time_sn.max(), 10000)
    
    is_enum = True if 'int' in date_type[col].__name__ else False
    cur_count, cur_loss = score(sub[col], predict_fn(sub.time_sn), is_enum)
    
    
    plt.plot(x, predict_fn(x))    
#     plt.plot(x, np.full_like(x, train[col].mean()) , c='r')  
    plt.show()

# %% [markdown]
# ## Visual the specific train_feature accross file

# %%
tmp = get_train_feature_multi_file(3, 'var031')
 
tmp.iloc[:3000, :3].plot(figsize=(20,5))
plot.show()

tmp.loc[pd.isna(tmp.iloc[:,0])]

# %%
print(cor.loc[f'{col_name}_1', f'{col_name}_2'])


step = 5000
begin = 4000 + step
end = 6000 +step



print(len(train_1.time_sn_1.loc[begin:end]) , len(train_2.time_sn_2.loc[begin:end]))

train_1[f'{col_name}_1'].loc[begin:end].plot()

train_2[f'{col_name}_2'].loc[begin:end].plot()

plt.show()

# %% [markdown]
# ###

# %%
train_1.loc[begin:end]

# %%
train_1.var034_1.iloc[begin:end].plot?

# %%
train_1.var034_1.iloc[begin:end].plot

# %%
tmp = std.groupby(['col', 'data_type'])['mean'].mean().sort_values().to_frame().reset_index()
print(tmp.columns)
tmp[tmp['data_type']=='int16']

# %%
columns = list(date_type.keys())
columns.remove('wtid')
columns = sorted(columns)
for wtid in sorted(range(1, 34), reverse=True):
    for col in columns:
        check_std(wtid,col)

# %%
logging.getLogger().setLevel(logging.DEBUG)


get_sub_template()

# %%
get_blocks().iloc[45]

# %%
get_blocks().iloc[6735]

# %%
tmp = get_train_ex(3).loc[173119-4000:173119][['time_sn', 'var002']]
tmp.loc[(tmp.time_sn > 1250000) & (tmp.time_sn < 1290000)]

# %%
feature_list = get_train_feature(1, 'var001')

len(feature_list)

# %%
bk.groupby(['wtid','col']).length.sum()

# %%
template = get_train_ex(1)
template.ts = pd.to_datetime(template.ts)
template['ts2'] = template.ts.shift(1)
template['gap'] = template.ts - template.ts2

template.gap = template['gap'].astype(int)//1000000000 
template['gap'].astype(int).hist()
plot.show()

# %%
template['gap'].value_counts().sort_index()
#template['gap'].drop_duplicates().sort_values()

# %%
 
        
col = 'var003'
get_result(1, col)

# %%
train = get_train_ex(1)
train.iloc[354983-3: 354983+3]

# %%
print(__doc__)

# Authors: Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>
#
# License: BSD 3 clause

import numpy as np

from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel


rng = np.random.RandomState(0)
X = rng.uniform(0, 5, 20)[:, np.newaxis]
y = 0.5 * np.sin(3 * X[:, 0]) + rng.normal(0, 0.5, X.shape[0])

# First run
plt.figure(0)
kernel = 1.0 * RBF(length_scale=100.0, length_scale_bounds=(1e-2, 1e3)) \
    + WhiteKernel(noise_level=1, noise_level_bounds=(1e-10, 1e+1))
gp = GaussianProcessRegressor(kernel=kernel,
                              alpha=0.0).fit(X, y)
X_ = np.linspace(0, 5, 100)
y_mean, y_cov = gp.predict(X_[:, np.newaxis], return_cov=True)
plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
plt.fill_between(X_, y_mean - np.sqrt(np.diag(y_cov)),
                 y_mean + np.sqrt(np.diag(y_cov)),
                 alpha=0.5, color='k')
plt.plot(X_, 0.5*np.sin(3*X_), 'r', lw=3, zorder=9)
plt.scatter(X[:, 0], y, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
plt.title("Initial: %s\nOptimum: %s\nLog-Marginal-Likelihood: %s"
          % (kernel, gp.kernel_,
             gp.log_marginal_likelihood(gp.kernel_.theta)))
plt.tight_layout()

# Second run
plt.figure(1)
kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e3)) \
    + WhiteKernel(noise_level=1e-5, noise_level_bounds=(1e-10, 1e+1))
gp = GaussianProcessRegressor(kernel=kernel,
                              alpha=0.0).fit(X, y)
X_ = np.linspace(0, 5, 100)
y_mean, y_cov = gp.predict(X_[:, np.newaxis], return_cov=True)
plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
plt.fill_between(X_, y_mean - np.sqrt(np.diag(y_cov)),
                 y_mean + np.sqrt(np.diag(y_cov)),
                 alpha=0.5, color='k')
plt.plot(X_, 0.5*np.sin(3*X_), 'r', lw=3, zorder=9)
plt.scatter(X[:, 0], y, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
plt.title("Initial: %s\nOptimum: %s\nLog-Marginal-Likelihood: %s"
          % (kernel, gp.kernel_,
             gp.log_marginal_likelihood(gp.kernel_.theta)))
plt.tight_layout()

# Plot LML landscape
plt.figure(2)
theta0 = np.logspace(-2, 3, 49)
theta1 = np.logspace(-2, 0, 50)
Theta0, Theta1 = np.meshgrid(theta0, theta1)
LML = [[gp.log_marginal_likelihood(np.log([0.36, Theta0[i, j], Theta1[i, j]]))
        for i in range(Theta0.shape[0])] for j in range(Theta0.shape[1])]
LML = np.array(LML).T

vmin, vmax = (-LML).min(), (-LML).max()
vmax = 50
level = np.around(np.logspace(np.log10(vmin), np.log10(vmax), 50), decimals=1)
plt.contour(Theta0, Theta1, -LML,
            levels=level, norm=LogNorm(vmin=vmin, vmax=vmax))
plt.colorbar()
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Length-scale")
plt.ylabel("Noise-level")
plt.title("Log-marginal-likelihood")
plt.tight_layout()

plt.show()

# %%
tmp['time_sn'] = (tmp.ts - pd.to_datetime('2018-07-01')).astype(int)/1000000000
 
# from datetime import timedelta
# tmp['gap'] = tmp['gap']/timedelta(hours=1)
# #tmp['gap'] = (  pd.to_datetime(tmp.ts2) - pd.to_datetime(tmp.ts) ) #/ np.timedelta64(1, 's')
# tmp.head()
#tmp.gap.astype(int)
tmp

# %%
train = get_train_ex(1) 



missing = train[pd.isna(train['var001'])].index

# %%
tmp.iloc[170590: 170599]

# %%
tmp_1.var001.iloc[200:300].plot()
plot.show()

# %%
tmp_1.var001.dropna().plot()
plot.show()

# %%
len(tmp_1.var003), len(tmp_1.var003.dropna())

# %%
from core.config import date_type
example = pd.read_csv('./input/submit_example.csv', dtype=date_type) 
example.head()


example.var016.drop_duplicates()

# %%
pd.value_counts(example.var016)

# %%
example.var001.iloc[0:3].astype(str)

# %%
example.var001.iloc[0:3].apply(lambda val : True if val==405.37 else False)

# %%
example.head()

# %%
plt.show()

# %%
from core import feature

# %%
template = pd.read_csv('./input/template_submit_result.csv') 

print(template.shape)
#template

# %%
template = pd.read_csv('./input/template_submit_result.csv') 

train = pd.read_csv('./input/001/201807.csv') 
print(train.shape)

template = template.set_index(['ts', 'wtid'])
train = train.set_index(['ts', 'wtid'])


train = train[train.index.isin(template.index)]

train.shape

tmp = template.combine_first(train)
print(tmp.shape)

# %%
 

tmp = get_sub_template()

tmp.head()

# %%
tmp = get_sub_template()

# %%
tmp.head(100)

# %%
train_01 = pd.read_csv('./input/001/201807.csv') 
train_01.head()
#del train_01

# %%
from core.feature import *
df = get_missing_analysis()

# %%
df

# %%
df.describe()

# %%
df.var001[:1].describe()

# %%
df.var001.astype(int).std()

# %%
np.finfo(np.float16).max

# %%
def get_analysis_enum():
    col_list = ['wtid','var053','var066','var016','var020','var047',  ]

    train_list = []
    for wtid in range(1, 34):
        wtid = str(wtid)
        train = pd.read_csv(f"./input/{wtid.rjust(3,'0')}/201807.csv", usecols=col_list)
        train = train.groupby(col_list).agg({'wtid':'count'})
        train.rename(index=str, columns={"wtid": "count"}, inplace=True)
        train = train.reset_index()
        print(train.shape)
        train_list.append(train)

    all = pd.concat(train_list)
    return all

enum_type = get_analysis_enum()

# %%
tmp = enum_type[['var053','var066','var016','var020','var047',]].drop_duplicates(['var053','var066','var016','var020','var047',])

# %%
enum_type.sort_values(['wtid', 'count', ], ascending=False)

# %%
for i in sorted((range(1, 34)),reverse=True):
    print(i)

# %%
import pprint
pprint.pprint(abc)

pprint.PrettyPrinter?

# %%
abc = {'a':'b', 'c':'d'}

# %%
tmp = get_blocks()

# %%
time_all = pd.DataFrame()
time_list = []
for i in range(1, 4):
    train = get_train_ex(i)
    print(len(train))
    time_list.append(train.ts)
    
time_all = pd.concat(time_list, axis=1)

# %%
time_all['min'] = time_all.iloc[:,:-3].min(axis=1)
time_all['max'] = time_all.iloc[:,:-3].max(axis=1)
time_all['gap'] = time_all['max'] - time_all['min']
time_all['gap'] =  time_all['gap'].astype(int).fillna(0)//1000000000
time_all.head()
